# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", #"Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

classifiers = [
    KNeighborsClassifier(2),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
#     GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %%
#data
data = pd.read_json('/home/hluu/teams/b09/extra/fever_train_challenges.jsonl', lines=True)
data
# Out:
#           id                                              claim     label  \
# 0
# 1      24435  Michael Folivi competed with ten teams from 20...   REFUTES
# 2      14802  Asiatic Society of Bangladesh(housed in Nimtal...  SUPPORTS
# 3      28540  Lindfield railway station has 3 bus routes, in...  SUPPORTS
# 4      71874  Mukaradeeb('Wolf's Den') is a city in Iraq nea...  SUPPORTS
# ...      ...                                                ...       ...
# 71287  40197  Monica Frassoni, European Green Party Spokespe...  SUPPORTS
# 71288  28692  Emil Roy was a native of Brighton, Massachuset...  SUPPORTS
# 71289  43014  Francisco Antonio Zea began studying in Medell...   REFUTES
# 71290  22198  Vernors, originally sold as Vernor’s, moved it...  SUPPORTS
# 71291  27530  Convergenza per il Friuli, a strong supporter ...  SUPPORTS
#
#                                                 evidence  \
# 0
# 1      [{'content': ['Michael Folivi_cell_1_2_0', 'Mi...
# 2      [{'content': ['Asiatic Society of Bangladesh_s...
# 3      [{'content': ['Lindfield railway station_sente...
# 4      [{'content': ['Mukaradeeb_sentence_1', 'Mukara...
# ...                                                  ...
# 71287  [{'content': ['Monica Frassoni_cell_0_5_1'], '...
# 71288  [{'content': ['Emil Roy_sentence_3', 'Emil Roy...
# 71289  [{'content': ['Francisco Antonio Zea_sentence_...
# 71290  [{'content': ['Vernors_sentence_11', 'Vernors_...
# 71291  [{'content': ['Convergence for Friuli_sentence...
#
#                                     annotator_operations  \
# 0
# 1      [{'operation': 'start', 'value': 'start', 'tim...
# 2      [{'operation': 'start', 'value': 'start', 'tim...
# 3      [{'operation': 'start', 'value': 'start', 'tim...
# 4      [{'operation': 'start', 'value': 'start', 'tim...
# ...                                                  ...
# 71287  [{'operation': 'start', 'value': 'start', 'tim...
# 71288  [{'operation': 'start', 'value': 'start', 'tim...
# 71289  [{'operation': 'start', 'value': 'start', 'tim...
# 71290  [{'operation': 'start', 'value': 'start', 'tim...
# 71291  [{'operation': 'start', 'value': 'start', 'tim...
#
#                        challenge
# 0
# 1            Numerical Reasoning
# 2                          Other
# 3                          Other
# 4      Combining Tables and Text
# ...                          ...
# 71287                      Other
# 71288                      Other
# 71289                      Other
# 71290                      Other
# 71291                      Other
#
# [71292 rows x 6 columns]

# %%
X, y = X_data_reshape, y_data

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_389/250721583.py in <module>
# ----> 1 X, y = X_data_reshape, y_data
#       2
#       3 X = StandardScaler().fit_transform(X)
#       4 X_train, X_test, y_train, y_test = \
#       5     train_test_split(X, y, test_size=.2)
#
# NameError: name 'X_data_reshape' is not defined

# %%
# TODO (Apply): All cross-validation

max_score = 0.0
max_class = ''
# iterate over classifiers
for name, clf in zip(names, classifiers):
    start_time = time()
    clf.fit(X_train, y_train)
    score = 100.0 * clf.score(X_test, y_test)
    print('Classifier = %s, Score (test, accuracy) = %.2f,' %(name, score), 'Training time = %.2f seconds' % (time() - start_time))
    
    if score > max_score:
        clf_best = clf
        max_score = score
        max_class = name

print(80*'-' )
print('Best --> Classifier = %s, Score (test, accuracy) = %.2f' %(max_class, max_score))
#plot the output of the various algorithms
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_389/3442581491.py in <module>
#       5 # iterate over classifiers
#       6 for name, clf in zip(names, classifiers):
# ----> 7     start_time = time()
#       8     clf.fit(X_train, y_train)
#       9     score = 100.0 * clf.score(X_test, y_test)
#
# NameError: name 'time' is not defined
